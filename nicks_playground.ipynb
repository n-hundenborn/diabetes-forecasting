# %%
import pandas as pd
import os
from raw_data import concat_df

# %%
df = concat_df()
df
# Out:
# Reading file: 2011.csv
# Reading file: 2012.csv
# Reading file: 2013.csv
# Reading file: 2014.csv
# Reading file: 2015.csv
#          Unnamed: 0  _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  \
# 0                 0     1.0     1.0  b'01202011'  b'01'  b'20'  b'2011'
# 1                 1     1.0     1.0  b'01142011'  b'01'  b'14'  b'2011'
# 2                 2     1.0     1.0  b'01062011'  b'01'  b'06'  b'2011'
# 3                 3     1.0     1.0  b'02012011'  b'02'  b'01'  b'2011'
# 4                 4     1.0     1.0  b'02012011'  b'02'  b'01'  b'2011'
# ...             ...     ...     ...          ...    ...    ...      ...
# 2380042      441451    72.0    11.0  b'12162015'  b'12'  b'16'  b'2015'
# 2380043      441452    72.0    11.0  b'12142015'  b'12'  b'14'  b'2015'
# 2380044      441453    72.0    11.0  b'12232015'  b'12'  b'23'  b'2015'
# 2380045      441454    72.0    11.0  b'12152015'  b'12'  b'15'  b'2015'
# ...
